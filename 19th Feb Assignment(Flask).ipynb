# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?
#
#     Flask is a micro web Framework written in Python. It is classified as microframework
#     because it doesnot require particular tools or libraries. It has no database abstraction
#     layer, form validation, or any other components where pre-existing third-party libraries
#     provide common functions. However, Flask supports extensions that can add application
#     features as if they were implemented in Flask itself. It's a python module that lets us
#     develop web applications easily. It has a small and easy-to-extend core. It is a micro
#     framework that doesn't include an ORM(Object, Relational Manager) or such features.
#
#     It does have many cool features like url routing, template engine.
#
#     Advantage of Flask Framework are:
#     1. Scalable: Flask's status as a microframework means that we can use it to grow a tech
#         project such as a web app incredibly quickly.
#     2. Flexible: This is the core feature of Flask, and one of its biggest advantage. To
#         paraphrase one of the principle of the Zen of Python, simplicity is better than
#         complexity, because it can be easily rearranged and moved around.
#     3. Easy to negotiate: Like django, being able to find our way around easily is key for
#         allowing web developers to concentrate on just coding quickly. At its core, the
#         microframework is easy to understand for web developers, not just saving them time
#         and effort but also giving them more control over their code and what is possible.
#     4. Lightweight: When we use this term in relation to a tool or framework, we're talking
#         about the design of it there are few constituent parts that need to be assembled and
#         reassembled , and it doesn't rely on a large number of extensions to function. This
#         desing gives web developers a certain level of control. Flask also supports modular
#         programming, which is hwere its functionality can be split into several interchangeable
#         mosules.
#     5. Documentation: Flask has a healthy number of examples and tips arranged in a structured
#         manner. This encourage developers to use the framework, as they can easily get introduced
#         to different aspects and capabilities of the tool.

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.
#
# ![Screenshot 2023-02-20 133952.png](attachment:ef4bd60e-67e3-4738-9abc-f3e813983cbb.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?
#
#     App routing means mapping the URLs to a specific function that will handle logic
#     for that URL. It is used to access some particular page in the web application.
#     To bind a function to an URL path we use the app.route decorator.
#
#     Use of app routes :
#     1.We can separate different areas of the app.
#     2.We can maintain the state in the app.
#     3.We can protect area of the app based on certain rules.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999
#
# ![Screenshot 2023-02-20 134648.png](attachment:7acd5f15-2737-414b-9b80-cba08be43322.png)
# ![Screenshot 2023-02-20 135838.png](attachment:e776f99a-2e3e-45e8-bfa7-8fe64b67dacf.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.
#
#     The url_for() function is used to build a URL to the specific function dynamically. The first
#     argument is the name of the specified function, and then we can pass any number of keywords
#     as arguments corresponding to the variable part of the URL.

# %%
from flask import Flask
app = Flask(__name__)

@app.route("/admin")
def admin():
    return "admin"

@app.route("/librarion")
def admin():
    return "librarion"

@app.route("/student")
def admin():
    return "student"

@app.route("/user/<name>")
def user(name):
    if name == 'admin':
        return redirect(url_for('admin'))
    if name == 'librarion':
        return redirect(url_for('librarion'))
    if name == 'student':
        return redirect(url_for('student'))
    
if __name__ == "__main__":
    app.run(debug = True)
